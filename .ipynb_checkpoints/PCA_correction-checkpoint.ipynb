# %% [markdown]
# # TP PCA

# %% [markdown]
# Regles:
#  - Pas le droit a sklearn a part les datasets
#  - Aucune boucle for est utilisée pour le calcul de la PCA

# %%
import numpy as np
from sklearn import datasets
from src.utils import biplot, plot_pca

# %% [markdown]
# Pour tester, on utilisera le dataset iris, un standard de la datascience. Ce dataset contient 3 types différent d'iris. On va grace a la PCA essayer d'y voir plus clair

# %%
iris = datasets.load_iris()
X = iris['data']
y = iris['target']
y_name = iris['target_names'][iris['target']]
feature_names = iris['feature_names']

# %% [markdown]
# Maintenant, c'est l'heure de coder notre PCA. Rappel: Doit etre fais que avec numpy.
# Tips:
#   - np.linalg.svd donne la decomposition svd. On preferera la SVD car plus rapide et plus stable que la decomposition en valeur propre de la covariance.
#   - La multiplication matricielle peut etre faite par np.dot ou l'operateur @.
#   - On rappelle que l'on doit centrer les données avant de faire la PCA
#   - On met a disposition 2 fonction dans src.utils plot_pca qui permet de aisement visualiser la reduction de dimension et biplot qui retourne le biplot de la pca.
# Completez les fonctions

# %%
class PCA:
    def __init__(self, n_components):
        self.n_components = n_components

    def fit(self, X):
        self.mean = X.mean(axis=0)
        X_tilde = X-self.mean
        self.U, self.d, self.V = np.linalg.svd(X_tilde, full_matrices=False)
        self.components = self.V[:self.n_components]
        eigen = self.d**2
        self.explained_variance = eigen[:self.n_components]/eigen.sum()

    def transform(self, X):
        X_tilde = X-self.mean
        X_trans = X_tilde@self.components.T
        return X_trans

    def fit_transform(self, X):
        self.fit(X)
        return self.transform(X)

# %% [markdown]
# #### Exercice 1.
# Questions:
# 1. Effectuez l'ACP sur les données iris. Projetez en 2d. Que pouvez vous conclure sur la relation des 2 especes
# 2. En plotant un biplot que pouvez vous conclure sur la signification des composants principaux? Qu'est ce qui distingue sentosa des 2 autres variétés?
# 3. Que constatez vous sur la part de variance de la composante 1? Que pouvez vous en conclure sur la signification de la variable 2?

# %% [markdown]
# ##### Question 1.1

# %%
pca = PCA(2)
pca.fit(X)
X_reduced = pca.fit_transform(X)
plot_pca(X_reduced,y,y_name)

# %% [markdown]
# On constate que setosa se distingue des 2 autres variétés

# %% [markdown]
# ##### Question 1.2

# %%
biplot(X_reduced, y,y_name, pca.components, feature_names)

# %% [markdown]
# On se rend compte que la longueur et la largeur des pétales sont largement corrélées. L'axe 1 est donc lié à la taille du pétale. On voit que setosa se caracteristique par une petite taille de pétal. En effet, il est inversement corrélés a l'axe 1. On se rend aussi compte que la largeur du sépal est orthogonal à l'axe 1. Donc, la taille du pétal n'a pas d'influence sur la largeur du sépal, les variables sont indépendantes. Quand a sa longeur, il est légérement corrélé à l'axe 1 donc a la taille du pétal. L'axe 2 est vraisemblament lié à la taille du sépal.

# %% [markdown]
# ##### Question 1.3

# %%
pca.explained_variance
# Out:
# array([0.92461872, 0.05306648])

# %% [markdown]
# On se rend compte que la composante 1 contient la plupart de la variance. Ainsi, cela veut dire que dans notre dataset, c'est la taille du petal qui predomine dans sa variabilité. La composante principale 2 est plutot au final du bruit des données qui ne permet pas de tirer de conclusions. On pourrait essayer d'obtenir plus d'info en normalisant les données par une des variables de sepal et ainsi avoir plus d'explications, mais, au vu du nombre faible de variable, ce n'est pas forcement necessaire.

# %% [markdown]
# #### Exercice 2:

# %%
digits = datasets.load_digits()
X = digits['data']
y = digits['target']
y_name = digits['target_names'][digits['target']]

# %% [markdown]
# Questions:
# 1. Quel est la dimensions des données de départ?
# 2. Effectuer une visualisation par PCA? Que constatez vous?
# 3. Quel critique pouvez vous emmettre sur cet embeding?

# %% [markdown]
# ##### Question 2.1

# %%
X.shape
# Out:
# (1797, 64)

# %% [markdown]
# Nos données sont de dimensions 64, difficile d'essayer d'interpreter les variables.

# %% [markdown]
# ##### Question 2.2

# %%
pca = PCA(2)
pca.fit(X)
X_reduced = pca.fit_transform(X)
plot_pca(X_reduced, y, y_name)

# %% [markdown]
# On se rend compte que l'on peut faire un bonne distinction entre les differents chiffres.

# %% [markdown]
# ##### Questions 2.3

# %% [markdown]
# La critique que l'on peut emettre c'est que il arrive a bien distinguer les chiffres qui ont des pixels qui comparés aux autres chiffres ont des coordonnées atypique comme le 3, le 4 ou le 0. Pour le 9 8 7 et 1, c'est plus difficile de faire la distinction. Cela est du au fait que notre PCA ne fait que des trnasformation linéaires, il n'a de plus pas de connaissance de la structure des chiffres et ne peux les discriminer que part les valeurs absolues des pixels
